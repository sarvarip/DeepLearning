# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

X_train = torch.FloatTensor([[0,0],[0,1],[1,0],[1,1]])
y_train = torch.FloatTensor([[0],[1],[1],[0]])

# %%
class SimpleModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.layer1 = nn.Linear(2,10)
    self.layer2 = nn.Linear(10,1)
    self.relu = nn.ReLU()
    self.sigmoid = nn.Sigmoid()

  def forward(self, x):
    x = self.relu(self.layer1(x))
    x = self.sigmoid(self.layer2(x))
    return x

model = SimpleModel()

# %%
citerion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(100):
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = citerion(outputs, y_train)
    loss.backward()
    optimizer.step()

    if epoch % 10 == 0:
        print(f'Epoch: {epoch}, Loss: {loss.item()}')
# Out:
# Epoch: 0, Loss: 0.7269434332847595
# Epoch: 10, Loss: 0.6732930541038513
# Epoch: 20, Loss: 0.6535480618476868
# Epoch: 30, Loss: 0.6302223205566406
# Epoch: 40, Loss: 0.5961740016937256
# Epoch: 50, Loss: 0.5497517585754395
# Epoch: 60, Loss: 0.49182218313217163
# Epoch: 70, Loss: 0.4259605407714844
# Epoch: 80, Loss: 0.3612409234046936
# Epoch: 90, Loss: 0.2983313798904419
